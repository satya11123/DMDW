# %%
import pandas as pd
dataset1=pd.read_csv('Toyota.csv')

# %%
dataset1
# Out:
#        No.  Price   Age     KM FuelType   HP  MetColor  Automatic    CC Doors  \
# 0        0  13500  23.0  46986   Diesel   90       1.0          0  2000     3
# 1        1  13750  23.0  72937   Diesel   90       1.0          0  2000     3
# 2        2  13950  24.0  41711   Diesel   90       NaN          0  2000     3
# 3        3  14950  26.0  48000   Diesel   90       0.0          0  2000     3
# 4        4  13750  30.0  38500   Diesel   90       0.0          0  2000     3
# ...    ...    ...   ...    ...      ...  ...       ...        ...   ...   ...
# 1431  1431   7500   NaN  20544   Petrol   86       1.0          0  1300     3
# 1432  1432  10845  72.0     ??   Petrol   86       0.0          0  1300     3
# 1433  1433   8500   NaN  17016   Petrol   86       0.0          0  1300     3
# 1434  1434   7250  70.0     ??      NaN   86       1.0          0  1300     3
# 1435  1435   6950  76.0      1   Petrol  110       0.0          0  1600     5
#
#       Weight
# 0       1165
# ...

# %%
dataset1.dropna(axis = 0, inplace=True)

# %%
import numpy as np
import matplotlib.pyplot as plt
plt.hist(dataset1['KM'], color = 'blue', edgecolor = 'white', bins = 5)
plt.title('Histogram of Kilometer')
plt.xlabel('Kilometer')
plt.ylabel('Frequency')
plt.show()

# %%
plt.scatter(dataset1['Age'],dataset1['Price'],c='blue')
plt.title('Scatter plot of Price vs Age of the Cars')
plt.xlabel('Age (months)')
plt.ylabel('Price (Euros)')
plt.show()

# %%
counts = [979,120,12]
fuelType = ("Petrol","Diesel","CNG")
index = np.arange(len(fuelType))
plt.bar(index, counts, color=['red', 'blue', 'cyan'])
plt.title("Bar plot of fuel types")
plt.xlabel("Fuel Types")
plt.ylabel("Frequency")
plt.xticks(index,fuelType,rotation = 90)
plt.show()

# %%
plt.hist(dataset1['Price'], color = 'blue', edgecolor = 'white', bins = 5)
plt.title('Histogram of Price')
plt.xlabel('Price')
plt.ylabel('Frequency')
plt.show()

# %%
dataset1.describe()
# Out:
#                No.         Price          Age     MetColor    Automatic  \
# count  1111.000000   1111.000000  1111.000000  1111.000000  1111.000000
# mean    707.868587  10774.997300    55.585959     0.675068     0.053105
# std     414.023750   3699.695538    18.829188     0.468561     0.224344
# min       0.000000   4350.000000     1.000000     0.000000     0.000000
# 25%     347.500000   8450.000000    43.000000     0.000000     0.000000
# 50%     703.000000   9900.000000    60.000000     1.000000     0.000000
# 75%    1069.500000  11950.000000    70.000000     1.000000     0.000000
# max    1435.000000  31275.000000    80.000000     1.000000     1.000000
#
#                 CC       Weight
# count  1111.000000  1111.000000
# mean   1569.463546  1073.870387
# std     185.935691    52.610513
# min    1300.000000  1000.000000
# 25%    1400.000000  1045.000000
# 50%    1600.000000  1070.000000
# 75%    1600.000000  1090.000000
# max    2000.000000  1615.000000

# %%
new_data = dataset1[[ "Price"]]
print(new_data.head())
# Out:
#    Price
# 0  13500
# 1  13750
# 2  13950
# 3  14950
# 4  13750

# %%
plt.figure(figsize = (10, 7))
new_data.boxplot()
# Out:
# <Axes: >

# %%
new_data = dataset1[[ "Price", "Age", "MetColor","Automatic","CC","Weight"]]
print(new_data.head())
# Out:
#    Price   Age  MetColor  Automatic    CC  Weight
# 0  13500  23.0       1.0          0  2000    1165
# 1  13750  23.0       1.0          0  2000    1165
# 2  13950  24.0       NaN          0  2000    1165
# 3  14950  26.0       0.0          0  2000    1165
# 4  13750  30.0       0.0          0  2000    1170

# %%
plt.figure(figsize = (10, 7))
new_data.boxplot()
# Out:
# <Axes: >
